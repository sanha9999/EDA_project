# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_result = pd.read_csv("Tottenham_Leicester_Round35.csv",index_col = 0)
df_result.head()
# Out:
#        ID Position             Player  Rating  Goal  Assist  Shots  SOT  Pass  \
# 0  143990      sub        Harry Winks     5.9     0       0      0    0     5
# 1  355855      sub   Dejan Kulusevski     7.6     0       2      0    0    11
# 2  279425      sub    Steven Bergwijn     5.9     0       0      0    0     2
# 3  322655      sub   Davinson Sánchez     0.0     0       0      0    0     0
# 4  240990      sub  Pierluigi Gollini     0.0     0       0      0    0     0
#
#    PA  DB  DB_W  TK  TK_S  YC  RC
# 0   4   0     0   1     0   0   0
# 1  11   4     3   2     2   0   0
# 2   2   1     0   0     0   0   0
# 3   0   0     0   0     0   0   0
# 4   0   0     0   0     0   0   0

# %%
df_lc = df_result[20:]
df_tot = df_result[:20]

df_tot = df_tot[df_tot['Rating']!=0.0].reset_index(drop=True)
df_lc = df_lc[df_lc['Rating']!=0.0].reset_index(drop=True)

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="토트넘 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '토트넘 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="오늘경기 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '오늘경기 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_lc.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_lc.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="레스터 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '레스터 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_lc.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_lc.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="레스터 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '레스터 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
df_tot["team"] = "Tottenham"
df_lc["team"] = "Brentford"
df = pd.concat([df_tot, df_lc], ignore_index=True)
df
# Out:
#         ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0   143990      sub            Harry Winks     5.9     0       0      0    0
# 1   355855      sub       Dejan Kulusevski     7.6     0       2      0    0
# 2   279425      sub        Steven Bergwijn     5.9     0       0      0    0
# 3    25604       GK            Hugo Lloris     6.4     0       0      0    0
# 4   323663       DC        Cristian Romero     7.4     0       0      1    0
# 5   117973       DC              Eric Dier     7.3     0       0      2    1
# 6   103837       DC             Ben Davies     7.0     0       0      1    0
# 7   328512      DMR          Emerson Royal     7.0     0       0      0    0
# 8   322611      DML         Ryan Sessegnon     6.9     0       0      0    0
# 9   101859       MC  Pierre-Emile Højbjerg     7.2     0       0      0    0
# 10  303657       MC      Rodrigo Bentancur     7.8     0       0      0    0
# 11   92508      FWR            Lucas Moura     6.2     0       0      2    0
# 12   83532       FW             Harry Kane     7.8     1       0      4    3
# 13   91909      FWL          Son Heung-Min     9.7     2       1      3    3
# 14   19545       GK      Kasper Schmeichel     6.1     0       0      0    0
# 15  141169       DC       Timothy Castagne     6.5     0       0      0    0
# 16  243552       DC         Daniel Amartey     6.2     0       0      0    0
# 17  317998       DC         Çaglar Söyüncü     6.4     0       0      0    0
# 18   42147      DMR        Marc Albrighton     5.8     0       0      0    0
# 19  396317      DML            Luke Thomas     5.9     0       0      0    0
# 20  345664       MC      Boubakary Soumaré     6.0     0       0      0    0
# 21   90278       MC         Nampalys Mendy     5.9     0       0      0    0
# 22  135366       MC            Ayoze Pérez     6.2     0       0      2    0
# 23  289253       FW      Kelechi Iheanacho     7.0     1       0      2    1
# 24  345560       FW            Patson Daka     6.5     0       0      1    1
# 25  106981      sub            Jamie Vardy     6.0     0       0      1    0
# 26  429681      sub            Lewis Brunt     6.1     0       0      0    0
# 27  136345      sub        Youri Tielemans     6.3     0       1      0    0
#
#     Pass  PA  DB  DB_W  TK  TK_S  YC  RC       team
# 0      5   4   0     0   1     0   0   0  Tottenham
# 1     11  11   4     3   2     2   0   0  Tottenham
# 2      2   2   1     0   0     0   0   0  Tottenham
# 3     24  18   0     0   0     0   0   0  Tottenham
# 4     49  40   2     2   3     3   0   0  Tottenham
# 5     45  35   0     0   1     1   0   0  Tottenham
# 6     54  45   2     2   2     2   1   0  Tottenham
# 7     30  23   2     1   4     3   0   0  Tottenham
# 8     26  20   1     0   5     3   0   0  Tottenham
# 9     55  48   1     1   4     2   0   0  Tottenham
# 10    38  32   1     1   4     4   1   0  Tottenham
# 11    11   8   3     0   0     0   0   0  Tottenham
# 12    27  16   2     0   1     0   0   0  Tottenham
# 13    27  23   2     1   1     0   0   0  Tottenham
# 14    22  13   0     0   0     0   0   0  Brentford
# 15    91  87   0     0   3     3   0   0  Brentford
# 16    90  82   0     0   5     4   1   0  Brentford
# 17    88  79   1     0   4     3   0   0  Brentford
# 18    71  51   5     2   1     0   1   0  Brentford
# 19    61  50   0     0   4     2   1   0  Brentford
# 20    42  33   2     1   1     0   0   0  Brentford
# 21    63  60   1     1   0     0   0   0  Brentford
# 22    25  22   4     3   2     0   0   0  Brentford
# 23    17  14   0     0   2     0   0   0  Brentford
# 24    16  13   1     0   5     4   0   0  Brentford
# 25     6   4   1     0   0     0   0   0  Brentford
# 26    21  21   1     1   0     0   0   0  Brentford
# 27    14  13   0     0   0     0   0   0  Brentford

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

fig = sns.barplot(data=df, x="Position", y="Rating", hue='team')
fig.set(title="포지션 별 평점 비교", ylabel="평점", xlabel="포지션")
# Out:
# [Text(0.5, 1.0, '포지션 별 평점 비교'), Text(0, 0.5, '평점'), Text(0.5, 0, '포지션')]

# %% [markdown]
# # 경기 총평
# * 우리 흥민이 월클 맞습니다~
# * 모우라와 차원이 다른 존재감을 보여준 클루솁스키... 리버풀 꺾어 보자 !!
