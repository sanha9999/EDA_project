# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_result = pd.read_csv("Tottenham_Newcastle_Round8.csv",index_col = 0)
df_result.head()
# Out:
#        ID Position              Player  Rating  Goal  Assist  Shots  SOT  \
# 0   93160      sub         Ryan Fraser     6.1     0       0      1    0
# 1  141486      sub        Jacob Murphy     6.4     0       0      1    0
# 2   40027      sub       Jonjo Shelvey     4.8     0       0      0    0
# 3   44847      sub  Federico Fernández     0.0     0       0      0    0
# 4   86454      sub       Jeff Hendrick     0.0     0       0      0    0
#
#    Pass  PA  DB  DB_W  TK  TK_S  YC  RC
# 0     7   7   0     0   0     0   0   0
# 1     7   5   1     0   2     2   0   0
# 2     9   8   0     0   2     1   2   0
# 3     0   0   0     0   0     0   0   0
# 4     0   0   0     0   0     0   0   0

# %%
df_nc = df_result[:20]
df_tot = df_result[20:]

df_tot = df_tot[df_tot['Rating']!=0.0].reset_index(drop=True)
df_nc = df_nc[df_nc['Rating']!=0.0].reset_index(drop=True)

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="토트넘 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '토트넘 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_nc.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_nc.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="뉴캐슬 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '뉴캐슬 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
df_tot["team"] = "Tottenham"
df_nc["team"] = "Newcastle"
df = pd.concat([df_tot, df_nc], ignore_index=True)
df
# Out:
#         ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0    25604       GK            Hugo Lloris     5.7     0       0      0    0
# 1   328512       DR          Emerson Royal     6.6     0       0      0    0
# 2   323663       DC        Cristian Romero     6.8     0       0      0    0
# 3   117973       DC              Eric Dier     5.8     1       0      1    0
# 4   362275       DL        Sergio Reguilón     6.7     0       1      0    0
# 5   101859      DMC  Pierre-Emile Højbjerg     8.1     0       1      1    1
# 6   364215      DMC           Oliver Skipp     6.7     0       0      0    0
# 7    92508      AMR            Lucas Moura     7.5     0       0      4    0
# 8   321389      AMC        Tanguy Ndombele     8.2     1       0      5    1
# 9    91909      AML          Son Heung-Min     7.4     1       0      1    1
# 10   83532       FW             Harry Kane     8.1     1       1      2    1
# 11   93160      sub            Ryan Fraser     6.1     0       0      1    0
# 12  141486      sub           Jacob Murphy     6.4     0       0      1    0
# 13   40027      sub          Jonjo Shelvey     4.8     0       0      0    0
# 14   70483       GK            Karl Darlow     6.0     0       0      0    0
# 15  109227       DR       Javier Manquillo     7.5     0       1      0    0
# 16   70099       DC           Ciaran Clark     6.7     0       0      1    0
# 17  105171       DC       Jamaal Lascelles     7.3     0       0      1    0
# 18   68648       DL           Matt Ritchie     6.3     0       0      0    0
# 19  136356      DMC           Isaac Hayden     6.7     0       0      0    0
# 20  135891       MR    Allan Saint-Maximin     7.0     0       0      2    0
# 21  342563       MC         Joseph Willock     6.2     0       0      0    0
# 22  342811       MC         Sean Longstaff     6.0     0       0      0    0
# 23  201755       ML              Joelinton     6.1     0       0      0    0
# 24  134115       FW          Callum Wilson     7.3     1       0      1    1
#
#     Pass  PA  DB  DB_W  TK  TK_S  YC  RC       team
# 0     22  18   0     0   0     0   0   0  Tottenham
# 1     44  30   1     0   5     5   1   0  Tottenham
# 2     60  49   0     0   7     4   0   0  Tottenham
# 3     65  57   0     0   0     0   0   0  Tottenham
# 4     67  57   2     1   3     1   0   0  Tottenham
# 5    103  99   3     1  13     9   0   0  Tottenham
# 6     77  74   0     0   4     4   0   0  Tottenham
# 7     45  36   6     5   4     0   0   0  Tottenham
# 8     66  61   9     4   4     4   0   0  Tottenham
# 9     38  35   2     0   0     0   0   0  Tottenham
# 10    25  23   3     1   0     0   0   0  Tottenham
# 11     7   7   0     0   0     0   0   0  Newcastle
# 12     7   5   1     0   2     2   0   0  Newcastle
# 13     9   8   0     0   2     1   2   0  Newcastle
# 14    29  19   0     0   0     0   0   0  Newcastle
# 15    18  16   0     0   7     6   0   0  Newcastle
# 16    37  32   0     0   2     2   1   0  Newcastle
# 17    42  32   1     1   2     1   0   0  Newcastle
# 18    42  30   0     0   5     3   0   0  Newcastle
# 19    22  20   4     2   8     4   1   0  Newcastle
# 20    24  14   9     7   0     0   0   0  Newcastle
# 21    27  25   2     1   3     2   0   0  Newcastle
# 22    24  23   1     1   2     2   1   0  Newcastle
# 23    40  31   3     0   4     2   1   0  Newcastle
# 24     6   3   3     1   1     1   0   0  Newcastle

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

fig = sns.barplot(data=df, x="Position", y="Rating", hue='team')
fig.set(title="포지션 별 평점 비교", ylabel="평점", xlabel="포지션")
# Out:
# [Text(0.5, 1.0, '포지션 별 평점 비교'), Text(0, 0.5, '평점'), Text(0.5, 0, '포지션')]
