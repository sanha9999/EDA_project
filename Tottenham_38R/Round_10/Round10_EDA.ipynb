# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_result = pd.read_csv("Tottenham_ManUtd_Round10.csv",index_col = 0)
df_result.head()
# Out:
#        ID Position            Player  Rating  Goal  Assist  Shots  SOT  Pass  \
# 0  131519      sub         Dele Alli     6.0     0       0      0    0    11
# 1  279425      sub   Steven Bergwijn     5.9     0       0      0    0    14
# 2  321389      sub   Tanguy Ndombele     6.3     0       0      0    0    25
# 3  322655      sub  Davinson Sánchez     0.0     0       0      0    0     0
# 4   94042      sub      Matt Doherty     0.0     0       0      0    0     0
#
#    PA  DB  DB_W  TK  TK_S  YC  RC
# 0   8   0     0   0     0   0   0
# 1  12   0     0   2     0   0   0
# 2  24   1     1   1     1   0   0
# 3   0   0     0   0     0   0   0
# 4   0   0     0   0     0   0   0

# %%
df_mu = df_result[20:]
df_tot = df_result[:20]

df_tot = df_tot[df_tot['Rating']!=0.0].reset_index(drop=True)
df_mu = df_mu[df_mu['Rating']!=0.0].reset_index(drop=True)

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="토트넘 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '토트넘 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="오늘경기 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '오늘경기 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_mu.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_mu.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="맨유 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '맨유 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_mu.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_mu.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="맨유 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '맨유 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
df_tot["team"] = "Tottenham"
df_mu["team"] = "ManUtd"
df = pd.concat([df_tot, df_mu], ignore_index=True)
df
# Out:
#         ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0   131519      sub              Dele Alli     6.0     0       0      0    0
# 1   279425      sub        Steven Bergwijn     5.9     0       0      0    0
# 2   321389      sub        Tanguy Ndombele     6.3     0       0      0    0
# 3    25604       GK            Hugo Lloris     5.5     0       0      0    0
# 4   328512       DR          Emerson Royal     7.3     0       0      0    0
# 5   323663       DC        Cristian Romero     6.4     0       0      0    0
# 6   117973       DC              Eric Dier     5.8     0       0      1    0
# 7   103837       DL             Ben Davies     5.6     0       0      1    0
# 8   101859      DMC  Pierre-Emile Højbjerg     6.2     0       0      0    0
# 9   364215      DMC           Oliver Skipp     5.8     0       0      0    0
# 10   92508      AMR            Lucas Moura     7.4     0       0      0    0
# 11  303908      AMC       Giovani Lo Celso     7.1     0       0      3    0
# 12   91909      AML          Son Heung-Min     6.2     0       0      3    0
# 13   83532       FW             Harry Kane     6.4     0       0      1    0
# 14   79554       GK           David de Gea     6.6     0       0      0    0
# 15   93206       DC         Raphaël Varane     7.2     0       0      0    0
# 16  100008       DC        Victor Lindelöf     6.9     0       0      0    0
# 17   99487       DC          Harry Maguire     7.2     0       0      0    0
# 18  331924      DMR      Aaron Wan-Bissaka     7.1     0       0      1    0
# 19  118244      DML              Luke Shaw     7.8     0       0      0    0
# 20  114397       MC                   Fred     6.9     0       0      1    1
# 21  123761       MC        Bruno Fernandes     7.4     0       1      0    0
# 22  336915       MC        Scott McTominay     7.7     0       0      1    0
# 23    5583       FW      Cristiano Ronaldo     8.5     1       1      2    1
# 24   24328       FW         Edinson Cavani     7.4     1       0      4    1
# 25  300299      sub        Marcus Rashford     6.9     1       0      1    1
# 26  109000      sub          Jesse Lingard     6.1     0       0      0    0
# 27   38128      sub          Nemanja Matic     6.9     0       1      0    0
#
#     Pass  PA  DB  DB_W  TK  TK_S  YC  RC       team
# 0     11   8   0     0   0     0   0   0  Tottenham
# 1     14  12   0     0   2     0   0   0  Tottenham
# 2     25  24   1     1   1     1   0   0  Tottenham
# 3     22  18   0     0   0     0   0   0  Tottenham
# 4     83  74   4     4   4     4   0   0  Tottenham
# 5     54  46   1     1   3     3   1   0  Tottenham
# 6     57  50   0     0   0     0   0   0  Tottenham
# 7     46  33   0     0   1     1   1   0  Tottenham
# 8     86  75   5     1   0     0   0   0  Tottenham
# 9     34  30   0     0   4     1   0   0  Tottenham
# 10    26  21   8     5   4     3   0   0  Tottenham
# 11    53  47   6     4   4     3   0   0  Tottenham
# 12    41  35   3     2   2     1   0   0  Tottenham
# 13    18  13   3     1   2     2   0   0  Tottenham
# 14    23  15   0     0   0     0   0   0     ManUtd
# 15    28  25   0     0   2     1   0   0     ManUtd
# 16    41  34   0     0   1     0   0   0     ManUtd
# 17    45  38   0     0   2     2   1   0     ManUtd
# 18    42  37   3     1   2     1   0   0     ManUtd
# 19    42  30   1     1   3     3   1   0     ManUtd
# 20    42  36   2     0   8     4   1   0     ManUtd
# 21    50  34   1     1   6     1   0   0     ManUtd
# 22    39  36   3     3   7     4   0   0     ManUtd
# 23    28  23   1     1   1     0   0   0     ManUtd
# 24    22  16   1     1   4     1   0   0     ManUtd
# 25     8   5   0     0   0     0   0   0     ManUtd
# 26     3   2   0     0   0     0   0   0     ManUtd
# 27     8   8   0     0   0     0   0   0     ManUtd

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

fig = sns.barplot(data=df, x="Position", y="Rating", hue='team')
fig.set(title="포지션 별 평점 비교", ylabel="평점", xlabel="포지션")
# Out:
# [Text(0.5, 1.0, '포지션 별 평점 비교'), Text(0, 0.5, '평점'), Text(0.5, 0, '포지션')]

# %% [markdown]
# # 경기 총평
# - 맨유한테 말 그대로 발림..
# - 참을만큼 참았다...누누 아웃!
