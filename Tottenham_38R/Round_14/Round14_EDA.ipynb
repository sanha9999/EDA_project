# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_result = pd.read_csv("Tottenham_Norwich_Round14.csv",index_col = 0)
df_result.head()
# Out:
#        ID Position             Player  Rating  Goal  Assist  Shots  SOT  Pass  \
# 0  322611      sub     Ryan Sessegnon     6.4     0       0      0    0    19
# 1  279425      sub    Steven Bergwijn     6.0     0       0      0    0     5
# 2   94042      sub       Matt Doherty     6.5     0       0      1    0    18
# 3  321389      sub    Tanguy Ndombele     0.0     0       0      0    0     0
# 4  240990      sub  Pierluigi Gollini     0.0     0       0      0    0     0
#
#    PA  DB  DB_W  TK  TK_S  YC  RC
# 0  16   4     1   1     0   0   0
# 1   5   0     0   2     0   0   0
# 2  14   0     0   1     1   0   0
# 3   0   0     0   0     0   0   0
# 4   0   0     0   0     0   0   0

# %%
df_nc = df_result[20:]
df_tot = df_result[:20]

df_tot = df_tot[df_tot['Rating']!=0.0].reset_index(drop=True)
df_nc = df_nc[df_nc['Rating']!=0.0].reset_index(drop=True)

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="토트넘 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '토트넘 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="오늘경기 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '오늘경기 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_nc.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_nc.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="노리치 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '노리치 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_nc.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_nc.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="노리치 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '노리치 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
df_tot["team"] = "Tottenham"
df_nc["team"] = "Norwich"
df = pd.concat([df_tot, df_nc], ignore_index=True)
df
# Out:
#         ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0   322611      sub         Ryan Sessegnon     6.4     0       0      0    0
# 1   279425      sub        Steven Bergwijn     6.0     0       0      0    0
# 2    94042      sub           Matt Doherty     6.5     0       0      1    0
# 3    25604       GK            Hugo Lloris     7.2     0       0      0    0
# 4   322655       DC       Davinson Sánchez     8.2     1       0      1    1
# 5   117973       DC              Eric Dier     6.9     0       0      0    0
# 6   103837       DC             Ben Davies     7.7     0       1      1    0
# 7   384063      DMR        Japhet Tanganga     6.5     0       0      0    0
# 8   362275      DML        Sergio Reguilón     6.4     0       0      0    0
# 9   101859       MC  Pierre-Emile Højbjerg     7.0     0       0      2    1
# 10  364215       MC           Oliver Skipp     7.2     0       0      2    1
# 11   92508      AMC            Lucas Moura     8.7     1       0      2    1
# 12   91909      AMC          Son Heung-Min     8.4     1       1      3    1
# 13   83532       FW             Harry Kane     7.4     0       0      5    2
# 14   22319       GK               Tim Krul     6.1     0       0      0    0
# 15  362103       DR             Max Aarons     6.4     0       0      0    0
# 16   86458       DC             Ben Gibson     6.1     0       0      0    0
# 17   86593       DC           Grant Hanley     6.6     0       0      2    0
# 18  399490       DC     Andrew Omobamidele     5.8     0       0      1    0
# 19  384143       DL       Brandon Williams     6.7     0       0      1    0
# 20  301243       MC      Pierre Lees-Melou     6.2     0       0      1    0
# 21   82917       MC           Kenny McLean     6.1     0       0      0    0
# 22  381255       MC          Billy Gilmour     5.8     0       0      2    0
# 23   25028       FW            Teemu Pukki     6.5     0       0      2    1
# 24  382368       FW              Adam Idah     5.7     0       0      1    0
# 25  404572      sub         Jacob Sørensen     6.2     0       0      0    0
# 26  136458      sub          Kieran Dowell     5.9     0       0      0    0
# 27  367480      sub         Joshua Sargent     6.1     0       0      0    0
#
#     Pass  PA  DB  DB_W  TK  TK_S  YC  RC       team
# 0     19  16   4     1   1     0   0   0  Tottenham
# 1      5   5   0     0   2     0   0   0  Tottenham
# 2     18  14   0     0   1     1   0   0  Tottenham
# 3     23  21   0     0   0     0   0   0  Tottenham
# 4     50  38   0     0   4     4   0   0  Tottenham
# 5     54  48   0     0   2     1   0   0  Tottenham
# 6     46  38   0     0   1     1   0   0  Tottenham
# 7     22  21   1     1   2     1   0   0  Tottenham
# 8      6   5   0     0   1     1   1   0  Tottenham
# 9     69  65   0     0   1     0   0   0  Tottenham
# 10    50  47   1     1   0     0   0   0  Tottenham
# 11    35  30   3     3   1     1   0   0  Tottenham
# 12    42  35   3     1   1     0   0   0  Tottenham
# 13    20  11   4     2   1     0   0   0  Tottenham
# 14    34  28   0     0   0     0   0   0    Norwich
# 15    46  39   3     2   5     5   0   0    Norwich
# 16   107  94   0     0   1     1   0   0    Norwich
# 17   106  99   0     0   2     2   0   0    Norwich
# 18    97  90   0     0   3     1   0   0    Norwich
# 19    66  59   2     1   5     3   0   0    Norwich
# 20    34  29   0     0   3     2   0   0    Norwich
# 21    50  45   2     1   0     0   0   0    Norwich
# 22    71  65   0     0   4     1   1   0    Norwich
# 23    18  13   4     2   1     1   1   0    Norwich
# 24    12   8   0     0   2     1   0   0    Norwich
# 25    10   8   1     1   0     0   0   0    Norwich
# 26    11   8   0     0   0     0   0   0    Norwich
# 27     5   4   1     1   1     1   0   0    Norwich

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

fig = sns.barplot(data=df, x="Position", y="Rating", hue='team')
fig.set(title="포지션 별 평점 비교", ylabel="평점", xlabel="포지션")
# Out:
# [Text(0.5, 1.0, '포지션 별 평점 비교'), Text(0, 0.5, '평점'), Text(0.5, 0, '포지션')]

# %% [markdown]
# # 경기 총평
# * 콘테 체제 엄청난 대승!!
# * 손흥민도 1골 1어시를 하는등 엄청난 활약을..
