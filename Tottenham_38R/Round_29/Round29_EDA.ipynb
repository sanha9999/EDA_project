# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_result = pd.read_csv("Tottenham_Brighton_Round29.csv",index_col = 0)
df_result.head()
# Out:
#        ID Position            Player  Rating  Goal  Assist  Shots  SOT  Pass  \
# 0   39308      sub     Danny Welbeck     6.4     0       0      0    0     4
# 1  386979      sub     Tariq Lamptey     6.0     0       0      0    0     6
# 2  399378      sub       Jakub Moder     6.1     0       0      0    0     3
# 3  362146      sub     Steven Alzate     0.0     0       0      0    0     0
# 4  425603      sub  Jeremy Sarmiento     0.0     0       0      0    0     0
#
#    PA  DB  DB_W  TK  TK_S  YC  RC
# 0   4   1     1   1     1   0   0
# 1   6   0     0   0     0   0   0
# 2   3   0     0   1     1   0   0
# 3   0   0     0   0     0   0   0
# 4   0   0     0   0     0   0   0

# %%
df_br = df_result[:20]
df_tot = df_result[20:]

df_tot = df_tot[df_tot['Rating']!=0.0].reset_index(drop=True)
df_br = df_br[df_br['Rating']!=0.0].reset_index(drop=True)

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="토트넘 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '토트넘 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="오늘경기 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '오늘경기 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_br.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_br.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="브라이튼 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '브라이튼 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_br.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_br.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="브라이튼 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '브라이튼 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
df_tot["team"] = "Tottenham"
df_br["team"] = "Brighton"
df = pd.concat([df_tot, df_br], ignore_index=True)
df
# Out:
#         ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0    25604       GK            Hugo Lloris     6.6     0       0      0    0
# 1   323663       DC        Cristian Romero     7.7     1       0      2    1
# 2   117973       DC              Eric Dier     7.0     0       0      0    0
# 3   103837       DC             Ben Davies     7.4     0       0      1    0
# 4    94042      DMR           Matt Doherty     6.3     0       0      1    0
# 5   362275      DML        Sergio Reguilón     7.2     0       0      2    2
# 6   101859       MC  Pierre-Emile Højbjerg     7.7     0       0      1    0
# 7   303657       MC      Rodrigo Bentancur     8.1     0       1      0    0
# 8   355855      AMC       Dejan Kulusevski     7.2     0       0      3    2
# 9    91909      AMC          Son Heung-Min     6.6     0       0      1    0
# 10   83532       FW             Harry Kane     7.7     1       0      6    2
# 11  279425      sub        Steven Bergwijn     6.0     0       0      0    0
# 12   92508      sub            Lucas Moura     6.2     0       0      0    0
# 13  328512      sub          Emerson Royal     6.2     0       0      0    0
# 14   39308      sub          Danny Welbeck     6.4     0       0      0    0
# 15  386979      sub          Tariq Lamptey     6.0     0       0      0    0
# 16  399378      sub            Jakub Moder     6.1     0       0      0    0
# 17  362151       GK         Robert Sánchez     6.4     0       0      0    0
# 18  110290       DR           Joël Veltman     6.2     0       0      0    0
# 19   75692       DC            Shane Duffy     6.3     0       0      2    0
# 20   86441       DC             Lewis Dunk     6.1     0       0      0    0
# 21  363496       DL         Marc Cucurella     6.4     0       0      1    0
# 22   71824      DMC            Pascal Groß     6.5     0       0      0    0
# 23  303096      DMC          Yves Bissouma     6.3     0       0      1    0
# 24  122926      AMR            Solly March     6.2     0       0      0    0
# 25  345319      AMC    Alexis Mac Allister     6.1     0       0      5    0
# 26  113994      AML       Leandro Trossard     6.7     0       0      2    0
# 27  119822       FW            Neal Maupay     5.9     0       0      4    0
#
#     Pass  PA  DB  DB_W  TK  TK_S  YC  RC       team
# 0     21  19   0     0   0     0   0   0  Tottenham
# 1     71  60   1     0   2     2   1   0  Tottenham
# 2     58  52   0     0   0     0   0   0  Tottenham
# 3     61  54   0     0   2     2   0   0  Tottenham
# 4     42  33   0     0   0     0   0   0  Tottenham
# 5     41  32   2     1   0     0   1   0  Tottenham
# 6     74  68   1     1   6     3   0   0  Tottenham
# 7     80  74   1     0   3     1   0   0  Tottenham
# 8     33  29   2     0   3     2   0   0  Tottenham
# 9     24  22   0     0   0     0   0   0  Tottenham
# 10    30  22   4     1   1     1   0   0  Tottenham
# 11     0   0   0     0   0     0   0   0  Tottenham
# 12     4   4   2     1   0     0   0   0  Tottenham
# 13    12  12   0     0   0     0   0   0  Tottenham
# 14     4   4   1     1   1     1   0   0   Brighton
# 15     6   6   0     0   0     0   0   0   Brighton
# 16     3   3   0     0   1     1   0   0   Brighton
# 17    30  15   0     0   0     0   0   0   Brighton
# 18    44  40   1     0   2     2   1   0   Brighton
# 19    61  56   0     0   1     0   0   0   Brighton
# 20    79  69   0     0   2     1   0   0   Brighton
# 21    52  41   1     1   1     1   0   0   Brighton
# 22    57  53   0     0   2     2   0   0   Brighton
# 23    31  30   0     0   2     2   0   0   Brighton
# 24    31  28   0     0   3     1   0   0   Brighton
# 25    33  28   0     0   2     2   0   0   Brighton
# 26    43  32   3     3   2     2   0   0   Brighton
# 27    22  19   1     1   1     1   1   0   Brighton

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

fig = sns.barplot(data=df, x="Position", y="Rating", hue='team')
fig.set(title="포지션 별 평점 비교", ylabel="평점", xlabel="포지션")
# Out:
# [Text(0.5, 1.0, '포지션 별 평점 비교'), Text(0, 0.5, '평점'), Text(0.5, 0, '포지션')]

# %% [markdown]
# # 경기 총평
# - 다행이도 이김.
# - 퐁당퐁당전적이 이어지고 있음..
