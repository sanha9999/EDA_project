# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_result = pd.read_csv("Tottenham_Leeds_Round26.csv",index_col = 0)
df_result.head()
# Out:
#        ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0  361787      sub       Jamie Shackleton     5.9     0       0      1    0
# 1   83459      sub                Rodrigo     6.2     0       0      2    1
# 2   69638      sub          Mateusz Klich     6.2     0       0      1    1
# 3  382564      sub  Crysencio Summerville     0.0     0       0      0    0
# 4  335718      sub    Kristoffer Klaesson     0.0     0       0      0    0
#
#    Pass  PA  DB  DB_W  TK  TK_S  YC  RC
# 0     5   5   0     0   0     0   0   0
# 1    15  10   1     0   0     0   1   0
# 2    25  23   1     1   4     2   1   0
# 3     0   0   0     0   0     0   0   0
# 4     0   0   0     0   0     0   0   0

# %%
df_ld = df_result[:20]
df_tot = df_result[20:]

df_tot = df_tot[df_tot['Rating']!=0.0].reset_index(drop=True)
df_ld = df_ld[df_ld['Rating']!=0.0].reset_index(drop=True)

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="토트넘 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '토트넘 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_tot.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_tot.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="오늘경기 worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '오늘경기 worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_mc.sort_values("Rating", ascending=False)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_mc.sort_values("Rating", ascending=False)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="리즈 선수의 평점", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '리즈 선수의 평점'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

word_df = df_mc.sort_values("Rating", ascending=True)[:5].reset_index(drop=True)

fig = sns.barplot(data=df_mc.sort_values("Rating", ascending=True)[:5], x="Player", y="Rating")
cnt = 0
for i in word_df["Rating"]:
    fig.text(x=cnt, y=i, s=i, color='black', ha="center",)
    cnt += 1
fig.set(title="리즈  worst", ylabel="평점", xlabel="선수")
# Out:
# [Text(0.5, 1.0, '리즈  worst'), Text(0, 0.5, '평점'), Text(0.5, 0, '선수')]

# %%
df_tot["team"] = "Tottenham"
df_ld["team"] = "Leeds"
df = pd.concat([df_tot, df_ld], ignore_index=True)
df
# Out:
#         ID Position                 Player  Rating  Goal  Assist  Shots  SOT  \
# 0    25604       GK            Hugo Lloris     6.8     0       0      0    0
# 1   323663       DC        Cristian Romero     7.4     0       0      0    0
# 2   117973       DC              Eric Dier     7.1     0       0      0    0
# 3   103837       DC             Ben Davies     8.0     0       0      1    1
# 4    94042      DMR           Matt Doherty     8.9     1       1      2    2
# 5   322611      DML         Ryan Sessegnon     7.8     0       1      2    1
# 6   101859       MC  Pierre-Emile Højbjerg     8.1     0       1      0    0
# 7   143990       MC            Harry Winks     7.0     0       0      0    0
# 8   355855      AMC       Dejan Kulusevski     8.5     1       0      4    2
# 9    91909      AMC          Son Heung-Min     9.0     1       0      4    4
# 10   83532       FW             Harry Kane     9.2     1       1      2    1
# 11  407154      sub          Dane Scarlett     6.2     0       0      0    0
# 12  279425      sub        Steven Bergwijn     6.2     0       0      0    0
# 13  328512      sub          Emerson Royal     6.1     0       0      0    0
# 14  361787      sub       Jamie Shackleton     5.9     0       0      1    0
# 15   83459      sub                Rodrigo     6.2     0       0      2    1
# 16   69638      sub          Mateusz Klich     6.2     0       0      1    1
# 17  380580       GK          Illan Meslier     7.1     0       0      0    0
# 18   82877       DR            Luke Ayling     5.7     0       0      1    0
# 19  355609       DC         Pascal Struijk     5.8     0       0      2    0
# 20  123232       DC         Diego Llorente     5.8     0       0      0    0
# 21  351252       DL           Junior Firpo     6.1     0       0      0    0
# 22  276205      DMC             Robin Koch     6.8     0       0      2    0
# 23  300447       MR               Raphinha     6.3     0       0      3    0
# 24   82972       MC           Adam Forshaw     5.9     0       0      2    0
# 25  134143       MC          Stuart Dallas     6.4     0       0      3    1
# 26  317896       ML          Jack Harrison     6.1     0       0      1    0
# 27  302313       FW           Daniel James     5.9     0       0      1    0
#
#     Pass  PA  DB  DB_W  TK  TK_S  YC  RC       team
# 0     24  21   0     0   1     0   0   0  Tottenham
# 1     64  59   0     0   2     2   0   0  Tottenham
# 2     64  57   0     0   0     0   0   0  Tottenham
# 3     31  26   0     0   2     2   0   0  Tottenham
# 4     46  41   1     1   1     0   0   0  Tottenham
# 5     11   9   1     0   1     1   1   0  Tottenham
# 6     65  58   1     1   4     3   0   0  Tottenham
# 7     55  50   1     0   2     1   0   0  Tottenham
# 8     34  31   5     4   2     1   0   0  Tottenham
# 9     35  32   5     4   0     0   0   0  Tottenham
# 10    36  26   4     2   0     0   0   0  Tottenham
# 11     1   1   1     1   0     0   0   0  Tottenham
# 12     7   7   1     0   0     0   0   0  Tottenham
# 13     1   0   2     0   0     0   0   0  Tottenham
# 14     5   5   0     0   0     0   0   0      Leeds
# 15    15  10   1     0   0     0   1   0      Leeds
# 16    25  23   1     1   4     2   1   0      Leeds
# 17    10  10   0     0   1     1   0   0      Leeds
# 18    54  49   0     0   3     3   0   0      Leeds
# 19    41  40   0     0   1     1   0   0      Leeds
# 20    51  48   0     0   3     2   0   0      Leeds
# 21    45  39   1     1   5     2   1   0      Leeds
# 22    46  40   0     0   1     0   0   0      Leeds
# 23    46  31   2     0   1     0   0   0      Leeds
# 24    41  36   0     0   7     5   0   0      Leeds
# 25    30  28   1     1   3     1   1   0      Leeds
# 26    21  12   1     1   1     0   0   0      Leeds
# 27    19  16   2     1   0     0   0   0      Leeds

# %%
plt.rcParams['font.size'] = 30
plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = 'NanumGothic'

fig = sns.barplot(data=df, x="Position", y="Rating", hue='team')
fig.set(title="포지션 별 평점 비교", ylabel="평점", xlabel="포지션")
# Out:
# [Text(0.5, 1.0, '포지션 별 평점 비교'), Text(0, 0.5, '평점'), Text(0.5, 0, '포지션')]

# %% [markdown]
# # 경기 총평
# * 손케듀오 드디어 역사를 쓰다!!
# * 해리케인은 그냥 토트넘 강산하..
