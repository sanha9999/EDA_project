# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers=headers)

r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.content, 'html.parser') # r.content or r.text
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#1a3151" name="theme-color">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport">
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.ru/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1642680096" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1642680152" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/gridview.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1642680152" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1642680153" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1642680153" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1642680153" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1642680146" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" rel="preload"/>
# <script src="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" type="text/javascript"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#         if (self == top) {
#             document.documentElement.style.display = 'block';
#         } else {
#             top.location = self.location;
#         }
#     </script>
# <noscript>
# <style>
#             html body *:not(.noscript) {
#                 display: none;
#             }
#         </style>
# <div class="noscript">
#             To use this site, please enable Javascript.        </div>
# </noscript>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 21073227 */ !function(n,i){function e(n,i){var e=an(n);if(!e)return e;if(""!=i)for(var t=0;t<i.length;t++){var r=u(i,t);"^"==r&&(e=e.parentNode),"<"==r&&(e=e.previousElementSibling),">"==r&&(e=e.nextElementSibling),"y"==r&&(e=e.firstChild)}return e}function t(n,i){var e=hn(i);return{x:n.clientX-e.left,y:n.clientY-e.top}}function r(n){for(var i=0,e=0;n;)i+=n.offsetLeft+n.clientLeft,e+=n.offsetTop+n.clientTop,n=n.offsetParent;return{x:i,y:e}}function h(n,i){var e=0,t=0,h=r(i);return(n.pageX||n.pageY)&&(e=n.pageX,t=n.pageY),(n.clientX||n.clientY)&&(e=n.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,t=n.clientY+document.body.scrollTop+document.documentElement.scrollTop),e-=h.x,t-=h.y,{x:e,y:t}}function d(n,i){return rn(i)?t(n,i):h(n,i)}function o(n,i){n.addEventListener?R(n,"click",i,!0):n.attachEvent&&n.attachEvent("onclick",function(){return i.call(n,window.event)})}function l(i,e){return n[w("c2V0VGltZW91dA==")](i,e)}function f(n){return parseInt(n.toString().split(".")[0],10)}function u(n,i){return n[i]}function p(){return Sn=(On*Sn+Pn)%Hn}function s(){return p()/(Hn-1)}function a(){return s()}function z(n,i){return n>i?n:i}function x(){for(var n="",i=65;i<91;i++)n+=c(i);for(var i=97;i<123;i++)n+=c(i);return n}function c(n){return u(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+u("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",n-32)}function w(n){var i,e,t,r,h,d,o,l=x()+"0123456789+/=",f="",p=0;for(n=n.replace(/[^A-Za-z0-9\+\/\=]/g,"");p<n.length;)r=l.indexOf(u(n,p++)),h=l.indexOf(u(n,p++)),d=l.indexOf(u(n,p++)),o=l.indexOf(u(n,p++)),i=r<<2|h>>4,e=(15&h)<<4|d>>2,t=(3&d)<<6|o,f+=c(i),64!=d&&(f+=c(e)),64!=o&&(f+=c(t));return f}function v(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(n){return"unknown"}}function R(n,i,e,t){t=t||!1;try{n.addEventListener(i,e,t)}catch(t){n.attachEvent&&n.attachEvent("on"+i,e)}}function m(n){if(!n)return"";for(var i=w("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),e="",t=0;t<n.length;t++){e+=i.indexOf(n[t])>-1?w("XA==")+n[t]:n[t]}return e}function g(n){if(!n)return"";var i="";return n.id&&n.id.length>0&&(i+="#"+m(n.id)),n.className&&n.className.length>0&&(i+="."+m(n.className).split(" ").filter(function(n){return n&&n.length>0}).join(".")),i}function k(n){In[n]=!1}function j(n,i){var e=Ln++;In[e]=!0;var t=function(i){return function(){n.call(null),In[e]&&l(t,i)}}(i);return l(t,i),e}function y(n){var i=!1;return Object.keys(n).forEach(function(e){i=i||n[e]}),!i}function b(n,i){return n&&(n.consents&&n.consents[i]||n.legitimateInterests&&n.legitimateInterests[i])}function q(i){return!!n.znihx0bcFlags.strictNCNA&&(b(i,2)&&b(i,7)&&b(i,9)&&b(i,10))}function W(n,i,e){var t=function(){return!!i()&&(e(),!0)};if(!t()){var r=j(function(){t()&&k(r)},250);t()}}function E(n){Z(n)}function Z(n){if(n.znihx476sdl&&!n.znihx6e8Injct){n.znihx6e8Injct=!0,n.znihxfd8Pc={},n.znihx9a6Oc=[],n.znihx734Am={},n.znihx02eAv={},n.znihxa8eAw={},n.znihxed3Rqr={},n.znihx307Rqq=[],n.znihx02eAvt={},n.znihxa90Ev={};var e=[];if(!n.znihx0bcFlags.welect.eenabled||EWYNOWelect()){if(znihx0bcFlags.ptf50ls){var t=znihx0bcFlags.ba844it,r=znihx0bcFlags.mb761el||10,h=znihx0bcFlags.ig1f2BP,d=function(){var n=D("style");n.type="text/css";var e=!1,t=D("style");t.type="text/css";var r=!1;return function(d,o){if(o)if("b"!==d||e){if("r"===d)if(r){var l=t,f=l.sheet;f.insertRule(o,0)}else r=!0,C(t,o),B(i.body,t)}else{if(e=!0,h)for(var u=0;u<h.length;u++)o=o.replace(new RegExp("([;{])"+h[u]+": [^;]+;","g"),"$1");var l="[^:;{",f="!important;";o=o.replace(new RegExp(l+"}]+: [^;]+\\s"+f,"g"),""),C(n,o),i.head.insertBefore(n,i.head.firstChild)}}}();if(t){if(t.length>r){for(var o=0,l=[0],u=[t[0]],p=1;p<r;p++){for(;l.indexOf(o)>-1;)o=f(a()*t.length);l.push(o),u[p]=t[o]}t=u,znihx0bcFlags.ba844it=u}for(var s={},z=0;z<t.length;z++){var x="string"==typeof t[z]?an(t[z]):t[z];if(x&&x instanceof Node){var c={element:x,co388so:{},rc7e1cls:Tn(7),co457tx:""};if(c.co457tx+="."+c.rc7e1cls+"{",!h||h&&-1===h.in ...
# var o=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2il7oP<hZ]hml<9[LjlYRxF7GlRnFrmhZhfwwieEx5vKW2"+n.znihx90fRnd+"QME7Eo5<X[k::NOsrheGyxkURSMpP}}9oMzV<vkQXZsZwMx1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2QW9SQVeUtG3Kvpu][W;|:hPT{}eGl:mKh9JUWxOyi58i2"+n.znihx90fRnd+"LMTSl56R\\H4HT5lTVZrmk}KSm:Qw;N\\Lr[9jzNL73WUGryV1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2w;qfJyXwR53okK8uV]}gZPrH<MUsS<Nl7NJ7qGqveUVS2"+n.znihx90fRnd+"IXVtqmV]6{Ts[U;YktS\\\\KfkUJ:HLw7ms{|FoMfx}Ey[\\\\g1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2T5OqvNV]3PLq}MY[}QHR\\Xp;[ffgRjHQV8uxOMHEPJjZ2"+n.znihx90fRnd+"GMU5rElqvMiX\\I{[xLW9TZGU8pvtJ;e|EpX3r:htF\\ML5IK1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2PmykUnoTiyuXFgNV;ghsjE<XwxlewV:YQ6TR6:Vr5|Sv2"+n.znihx90fRnd+"YKGfZWuE3f3g|46]srqLPl<WyvNQOjKqhwVik4o593]Fn9}1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2R4NKqj4}NZl[jfZ}SU4iiYXpjVF{x}P6vL|[\\tUx7jFX2"+n.znihx90fRnd+"XQU4rf}v3pHZV8fW]wRF};{zNrlue|tWtZnw43ivMQziXIY1jli",-3)],l=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2OE9sUeiswZyQI]m5tRvesgmS7UOZH<7vik}xVWninf9f2"+n.znihx90fRnd+"TWRWtG3gi;|uq5n}:;{83qeez:Iw7t}w]usP4T4i5VpssMX1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2INQqHLfykHPjfHl<HF[rhlmhtW7}[FLZOr7NF4n<Y;qW2"+n.znihx90fRnd+"LOO;:nsNFMEXpHGkyn8omoneHp{pjSoNsu7w\\5xz59MzYmU1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2]3\\H8vIgZeZGUX7YYnJfk35jzPf8PP{hfR7zEm[UtMyS2"+n.znihx90fRnd+"X[VNIk7zHxfzyWnQ\\GyWV||s:Jlr93xJ9M<Z4ug\\nww7\\:;1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2}6hN]]MqJwQOU\\YxpQ<u\\sU:OkQHzN3l3UR7M|tF3hjM2"+n.znihx90fRnd+"TJZT6:qjNSYW9V;joSztYeVr9n3Pw;9Z<;L}\\ikQ7ENUo}{1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2]VKek<kKP;H<h;tH<V}O:<TOQ<;gl4rivQg[kmkWXYHt2"+n.znihx90fRnd+"MY]He64HXSf6nnGl66YK3eteIryHPjO[K7q<x]qLy3HY6F81jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2eTRKsOovZRNNgjoZOnIizyuk:36:{T5ki7K[i\\G4]nOK2"+n.znihx90fRnd+"Y\\NOKWV\\V|GIZxhJ|rMhhXpkx|o]IQ\\l{j74eZQ]4v\\:8<i1jli",-3)],u=o[1*f(6*e.y/this.offsetHeight)+f(1*e.x/this.offsetWidth)],p=l[1*f(6*e.y/this.offsetHeight)+f(1*e.x/this.offsetWidth)];mn(n,u,p,"_blank")}}),B(p,l),ln(u,p),n.znihxdb6e4.a[9440]=p,F([{applyAdText:!0}],p,9440),Mn(p,9440,Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2<5tMpL{sPGpMPINEHf;po9wIg4oq<]zp[em[<5tFSfO42"+n.znihx90fRnd+"ZVSJvpRso:KXiGo6PlnUmI[V4{n{eSfYPNWqgEuqe|Z:;IS1jli",-3)),H(9440,e,!0)}}},function(){H(9440,e,!1)})}function s(i,e,r,h){r||xn(Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2;7WjuEQ6SRLQR8F\\hvQoM;n|hpgHS]\\\\Lohw:nzqih|r2"+n.znihx90fRnd+"\\VGhUHssw7Gm8zvkJn9NS3vI<rT5OEJST]5W7yR|XG7}zIp1jli",-3),function(){if(!r){r=!0;var l=this;if(l.height<2)return void H(9931,e,!1);if(h==n.znihx90fRnd){var u=i,p=D("div");t[""+w(Zn(w("V1o8bGRae29bMzRWUGpAQA=="),-3))]=p,sn(p,"wzedoifNG"),pn(p,"xVnTlM ");var s=l;n.znihx734Am[9931]&&(O(n.znihx734Am[9931]),n.znihx734Am[9931]=!1),o(s,function(i,e){if(!n.znihxfd8Pc[9931]){i.preventDefault(),i.stopPropagation();for(var e=d(i,this),t=0;t<n.znihx9a6Oc.length;t++){var r=n.znihx9a6Oc[t];if(9931==r.p&&e.x>=r.x&&e.x<r.x+r.w&&e.y>=r.y&&e.y<r.y+r.h){if(r.u){var h=r.t.length>0?r.t:"_self";h=0==i.button&&i.ctrlKey?"_blank":h,mn(n,r.u,r.u,h,!0)}return}}var o=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2S3OQy{Ut9q{<ONTZT|Yyp}wVzOzG43QZ]ZgGis84kE4r2"+n.znihx90fRnd+"XZI}YJkZtyMq:viqkswm4GxFw3<9zFU\\WlIo<JVPf5XF34x1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2;mW44UX[IK9pM5EuX[qguVgLVh]svKz\\sXQuusm8kKjL2"+n.znihx90fRnd+"LU\\H8mkT9RM84<n5UIFW}wM6n]jqXRHV:Wr}gXiUr3o]zNL1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2ZtEwLXtMeOFeHtNkQKxStkVGunFUY]ZGM;uy9WVYVlPo2"+n.znihx90fRnd+"QVJTlRWph4Vlg;loNvYvxPis;<SnP55|in<T;wvKQnfSYrz1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2[5RGNejjRl:e{ZylRrQ:N7Yh{QxvefxxF4|<y\\LiSINs2"+n.znihx90fRnd+"NR[Io44RguHhw{t\\qoV|m:wgqlpOFeySviJ[JfmSomSoVQM1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2{PtNz5O3U::M<S3w{9lUhu5P5fekVWN}UIfeZJgOhEko2"+n.znihx90fRnd+"WJGz;VmW}XYj{{NPH5ysX8zLzrI<x:{{GE8LtiU9LZO;YUF1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2zIg]WZuM6G;<[VN ...
# H(8939,e,!1)})}function Z(i,t,r){var h=e(""+w(Zn(w("TDZRcGdKTHw="),-3)),"");h?t(h,!i,!1,n.znihx90fRnd):r(10143,!i,!1)}function V(i,e,r,h){r||xn(Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh29GhGSPpz7MtywI:eQUonjuHSx7PiO8S<4lSuXJmVpF;o2"+n.znihx90fRnd+"RMUYqYwREVQVHrkq}3<Wzfv65]EFZz4NW5|R5LrLmy<z4:41jli",-3),function(){if(!r){r=!0;var l=this;if(l.height<2)return void H(10143,e,!1);if(h==n.znihx90fRnd){var u=i,p=D("div");t[""+w(Zn(w("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Md1FUQEA="),-3))]=p,sn(p,"nqXVcj");var s=l;n.znihx734Am[10143]&&(O(n.znihx734Am[10143]),n.znihx734Am[10143]=!1),o(s,function(i,e){if(!n.znihxfd8Pc[10143]){i.preventDefault(),i.stopPropagation();for(var e=d(i,this),t=0;t<n.znihx9a6Oc.length;t++){var r=n.znihx9a6Oc[t];if(10143==r.p&&e.x>=r.x&&e.x<r.x+r.w&&e.y>=r.y&&e.y<r.y+r.h){if(r.u){var h=r.t.length>0?r.t:"_self";h=0==i.button&&i.ctrlKey?"_blank":h,mn(n,r.u,r.u,h,!0)}return}}var o=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2lXng4}[w6JL[egtE]wi\\J|85UJO\\OfJ6NW:|Eo5OuwNn2"+n.znihx90fRnd+"\\FIpmKxiLFywyGl7rh3X}p[\\7SY\\lMRh3]weHQUtOU;fzps1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Gi{YoUw7YW7Eov7jnexTgViugTkIg{hYH;{8E<t:pg::2"+n.znihx90fRnd+"LHLuqNW93i7Ji;q:sJO6xt]<t]G3L<IGkE{EK4lhOf}nPHS1jli",-3)],l=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2:5pQ{9Fz}38ylPYVlvi[Lv9Y9o}\\uWLtxSOtVomm]GGH2"+n.znihx90fRnd+"ILQNyn:sjpovSgzYq}{X}F]ymPThWfM4WTYO4{:VoEo}qm[1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2tumwY|9<;tpsJ4E|XYO434i]l3yJZ9qHIYztoTgHiT|T2"+n.znihx90fRnd+"ZW[z8ipqTFZ\\nVuHuywuWpe|}:WXWuqP{zx\\LFunzn|e8M\\1jli",-3)],u=o[2*f(1*e.y/this.offsetHeight)+f(2*e.x/this.offsetWidth)],p=l[2*f(1*e.y/this.offsetHeight)+f(2*e.x/this.offsetWidth)];mn(n,u,p,"_blank")}}),B(p,l),B(u,p),n.znihxdb6e4.a[10143]=p,Mn(p,10143,Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2tR]nHzele4U\\:<vnwr{|Z|oG96<iWOJ8{:KRLfnI}W{82"+n.znihx90fRnd+"WU\\ZlyJ9<FsJKZhUjmNkQ5|zJlJTWm3zYT}j|9ImyV9yPor1jli",-3)),H(10143,e,!0)}}},function(){H(10143,e,!1)})}function T(i,t,r){var h=e(""+w(Zn(w("TDZRcGdKTH0="),-3)),"");h?t(h,!i,!1,n.znihx90fRnd):r(10144,!i,!1)}function G(i,e,r,h){r||xn(Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2wK\\59mVh:FOwwXSSzTFgy7T{n:FjHumkgO8<N4\\MUt;m2"+n.znihx90fRnd+"]\\PyiMzj;GSUPZx5<OzeYGLzgQIjTQmG;RM6rePEK9]yrPM1jli",-3),function(){if(!r){r=!0;var l=this;if(l.height<2)return void H(10144,e,!1);if(h==n.znihx90fRnd){var u=i,p=D("div");t[""+w(Zn(w("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Qd1FUQEA="),-3))]=p,sn(p,"yYfdxj"),pn(p,"BNwgUI ");var s=l;n.znihx734Am[10144]&&(O(n.znihx734Am[10144]),n.znihx734Am[10144]=!1),o(s,function(i,e){if(!n.znihxfd8Pc[10144]){i.preventDefault(),i.stopPropagation();for(var e=d(i,this),t=0;t<n.znihx9a6Oc.length;t++){var r=n.znihx9a6Oc[t];if(10144==r.p&&e.x>=r.x&&e.x<r.x+r.w&&e.y>=r.y&&e.y<r.y+r.h){if(r.u){var h=r.t.length>0?r.t:"_self";h=0==i.button&&i.ctrlKey?"_blank":h,mn(n,r.u,r.u,h,!0)}return}}var o=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2L7OQnG{{TeLXlkKW48EVkYf4kiOoJf[|HV]4[JmG5XxP2"+n.znihx90fRnd+"OFXq4L8S79T;zlxvQ8r{ny4]r[qEnmWpF\\oGmVNH756n8M]1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2rHZ9o:EPmpzMtoUIVpTiJVKxetiSK7EpPPtk7PVxInKH2"+n.znihx90fRnd+"OSN7z[f[Ihr\\lfFu|uYoF9i77|y5n7GF657\\[rUtyXILIUi1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2M9nPtTP4YHprYqIrl{F\\<hp<jqEGPNn}5[[zfV4]6;Jl2"+n.znihx90fRnd+"IT[}88I<hpyPShhn|;ISJpXgf5XZkPgQfj\\<x9hs9RJNuvY1jli",-3)],l=[Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2\\{fR:RwfR{3WE}UhUk\\iF3fQNM;UFyrUzL:l5<4n\\}Is2"+n.znihx90fRnd+"H\\JlPo<{wpwVsyyhJVujhZpYn<Z8{WUwFivK7zqIYq{}eHt1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2F9\\mR46EG:YzqGp4Zw}Wi7I]y7pPhZOjE;}UfYki5sGl2"+n.znihx90fRnd+"FHZX54GhNyJWEz:QYVSfWe]Lh4}83lEqeVUnnLxI\\JJp[:u1jli",-3),Zn("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh26:wQ}{8:[}E6Ovo|4hk4LUVhs6nU7<ut:zXRh{t[ItSF2"+n.znihx90fRnd+"P]NUk|W:N|tSwG\\{E5hL|4hkZKY43QoyqYH;JSLylOUm;{r1jli",-3)],u=o[3*f(1*e.y/this.offsetHeight)+f(3*e.x/this.offsetWidth)],p=l[3*f(1*e.y/this.offsetHeight)+f(3*e.x/this.offsetWidth)];mn(n,u,p,"_blank")}}),B(p,l),B(u,p),n.znihxdb6e4.a[101 ...
# ""===i?"":"."===i[0]?(n.classList.remove(i.slice(1)),n.classList.add(e),"."+e):(n.id=e,"#"+n.id.trim())}function Tn(n){for(var i="",e="CBADEFGHIJKLMNOPQRSTUVWXYZcbadefghijklmnopqrstuvwxyz",t=0;t<n;t++)i+=u(e,f(a()*e.length));return i}function Gn(i,e,t,r){var h=i.classList.item(0)?"."+i.classList.item(0):"",d=Vn(i,h,Tn(6)),o=i.id.trim()?"#"+i.id.trim():"",l=Vn(i,o,Tn(6)),f="",u="";if(n[V("fmdsqfEtqqf",-12)])for(var p=n[V("fmdsqfEtqqf",-12)],s=p,a=0;a<p.cssRules.length;a++)if(u=p.cssRules[a].cssText,""!==h&&u.indexOf(h)>-1?f=u.replace(h,d):""!==o&&u.indexOf(o)>-1&&(f=u.replace(o,l)),""!==f){s.deleteRule(a--);s.insertRule(f,p.cssRules.length),f=""}i.classList.remove("znihxHid"),t&&0===i.scrollHeight&&0===i.scrollWidth&&(r[t]&&r[t].hidden>3?r[t].ignore=!0:r[t]?r[t].hidden++:r[t]={hidden:1});for(var z=0;z<e.length;z++)i.parentNode===e[z]&&Gn(e[z],e,void 0,void 0)}function Nn(n,i){return!i[n]||!i[n].ignore}function Fn(){var i,e,t,r=[],h=0,d=[];n.znihx0bcFlags.mutationRecord=d;j(function(){i=Object.keys(n.znihxdb6e4.a);for(var o=0;o<i.length;o++)r[o]=i[o];t=Object.values(n.znihxdb6e4.w);for(var l=0;l<r.length;l++){var f=r[l];e=n.znihxdb6e4.a[f].firstChild?n.znihxdb6e4.a[f].firstChild:n.znihxdb6e4.a[f],0===e.scrollHeight&&0===e.scrollWidth?Nn(f,d)&&("IMG"===e.nodeName&&(e=e.parentNode),Gn(e,t,f,d)):d[f]&&(d[f]={hidden:0})}h++},500)}function Mn(e,t,r){if(n.znihx02eAv[t]||(n.znihx02eAv[t]=0),n.znihxa8eAw[t]||(n.znihxa8eAw[t]=0),!(n.znihx02eAv[t]>16||n.znihx02eAv[t]>0&&!n.znihxa90Ev[t])){var h=e.getBoundingClientRect();if(void 0===e.width)var d=e.offsetHeight,o=e.offsetWidth;else var d=e.height,o=e.width;var l=h.left+o,f=h.top+d,u=i.documentElement,p=0,s=0;if(n.innerWidth&&n.innerHeight?(p=n.innerHeight,s=n.innerWidth):!u||isNaN(u.clientHeight)||isNaN(u.clientWidth)||(p=u.clientHeight,s=u.clientWidth),d>0&&o>0&&0<=f&&f<=p&&0<=l&&l<=s&&"visible"==i.visibilityState&&++n.znihxa8eAw[t]>=20){n.znihxa8eAw[t]=0;var a=function(){n.znihxed3Rqr[t]=!0;var i=function(){n.znihx307Rqq.length>0?n.znihx307Rqq.shift():n.znihxed3Rqr[t]=!1};xn(r,i,i),n.znihx02eAv[t]++};n.znihxed3Rqr[t]?n.znihx307Rqq.push(a):n.znihx307Rqq.length>0?(n.znihx307Rqq.shift(),n.znihx307Rqq.push(a)):a()}n.znihx02eAvt[t]=n.setTimeout(function(){Mn(e,t,r)},50)}}function Un(i,e,t){function r(n){for(var i="",e=0;e<n.length;e++)""!=i&&(i+=","),i+='"'+n[e]+'"';return i}var h=new XMLHttpRequest;h[w("YWRmX2lnbm9yZQ==")]="PM",h.responseType="text",h.open("POST",t,!0),h.setRequestHeader("Content-Type","text/plain"),h.onreadystatechange=function(){if(4===h.readyState){if(200===h.status){JSON.parse(h.responseText).privateMode&&(n.znihxnl=!0,n.znihxdb6etc.pm=!0)}else n.znihxnl=!1;n.znihxdb6etc.pmd=!0,I()}};var d="Requests";h.send('{"failed'+d+'":['+r(i)+'],"successful'+d+'":['+r(e)+"]}")}function Xn(n,i){for(var e=0;e<i.length;e++)if(i[e]===n)return e;return-1}try{var Hn=2147483648,On=1103515245,Pn=12345,Sn=function(){function n(i,e){var t,r=[],h=typeof i;if(e&&"object"==h)for(t in i)try{r.push(n(i[t],e-1))}catch(n){}return r.length?r:"string"==h?i:i+"\0"}var i="unknown";try{i=n(navigator,void 0).toString()}catch(n){}return function(n){for(var i=0,e=0;e<n.length;e++)i+=n.charCodeAt(e);return i}(n(window.screen,1).toString()+i)+100*(new Date).getMilliseconds()}(),Ln=0,In=[],Qn={};R(n,"message",function(i){if(null!==i.data&&"object"==typeof i.data)try{var e=i.data,t=document.createElement("a");if(t.href=i.origin,"null"===i.origin||window.location.hostname!=t.hostname&&"www.transfermarkt.com"!=t.hostname)return;if("cc"==e.c)vn(zn(e.d+" > *"),function(n,i){fn(i)});else if("cs"==e.c)if(n[V("fmdsqfEtqqf",-12)])for(var r=n[V("fmdsqfEtqqf",-12)],h=e.d.replace(new RegExp(w("fVxzK30="),"g"),function(n){return"}}"}),d=h.replace(new RegExp(w("fVtefV0="),"g"),function(n){return n[0]+"rll123rnd"+n[1]}).split("rll123rnd"),o=0;o<d.length;o++)r[V("uzeqdfDgxq",-12)](d[o],r.cssRules.length);else{var r=D("style");r.type="text/css",C(r,e.d),B(Kn,r)}else if("am"==e.c)n.znihxdb6e4.a[e.d.i]?O(e.d.u):n.znihx734Am[e.d. ...
# document.createElement=function(){var e=i.apply(this,arguments);return R(e,"error",n.EWYNOnwld.error.listener,!0),R(e,"load",n.EWYNOnwld.load.listener,!0),e}}(document.createElement)}(),function(){function i(){!function(){for(var i=0;i<n.EWYNOnwld.load.events.length;i++){var e=Xn(n.EWYNOnwld.load.events[i],n.EWYNOnwld.error.events);e>-1&&n.EWYNOnwld.error.events.splice(e,1)}}(),n.EWYNOnwld.error.events.length>0&&n.EWYNOnwld.load.events.length>0?Un(n.EWYNOnwld.error.events,n.EWYNOnwld.load.events,Zn("22plwvhoi1qhw2wpfrp2LSuomsoUy\\vWeWksLMH4EHWsrj[{7[|Ie[eFYgoJ}vji2"+n.znihx90fRnd+"OMMYq\\WmRwEqJoPQel3Ye{w;\\;]Gt94U}\\4i:R7z366IO:N1jli",-3)):(n.znihxdb6etc.pmd=!0,I())}var e=0,t=0,r=0,h=0,d=0,o=0,l=j(function(){r=n.EWYNOnwld.error.events.size,h=n.EWYNOnwld.load.events.size,e=r+h,d<=10?(e-t==0&&d>0&&o++,o>4&&(k(l),i(),o=0)):(k(l),i()),t=e,d++},500)}())}else n.znihxnl=!0,n.znihxdb6etc.pmd=!0,I();else n.znihxdb6etc.pmd=!0,I();try{n.addEventListener?R(n,w("YWRuZGRuZC5pbml0"),K):n.attachEvent&&n.attachEvent(w("YWRuZGRuZC5pbml0"),K),"complete"===i.readyState?K():(-1==v().search("Firefox")&&(i.addEventListener?R(i,w("RE9NQ29udGVudExvYWRlZA=="),K):i.attachEvent&&i.attachEvent("onreadystatechange",function(){"complete"===i.readyState&&K()})),R(n,"load",K))}catch(n){K()}}catch(n){}}(window,document); /* 129bd */
# </script>
# <div class="werbung werbung-header"><!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                           window.googletag = window.googletag || {cmd: []};
#                           googletag.cmd.push(function() {
#                             googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600]], "div-gpt-ad-1621527521939-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600]], "div-gpt-ad-1621528123398-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90]], "div-gpt-ad-1621528173524-0")
#                             .addService(googletag.pubads());
#                              googletag.pubads().enableLazyLoad({
#                                 fetchMarginPercent: 500,
#                                 renderMarginPercent: 200,
#                                 mobileScaling: 2.0});
#                             googletag.pubads().setCentering(true);
#                             googletag.pubads().enableSingleRequest();
#                             googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                             googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                             googletag.enableServices();
#                           });
#                         </script>
# <!-- End GPT Tag --></div></link></link></meta></meta></head>
# <body class="" data-cmp-layer-id="575843" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage" style="overflow-y: scroll;" x-ms-format-detection="none">
# <tm-language-hint></tm-language-hint>
# <div class="navibalken hide-for-small" id="navibalken"></div>
# <div id="main">
# <header class="tm-header">
# <div class="tm-header__box">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# </div>
# <div class="tm-header__social-box">
# <a class="header__social-link" href="https://www.facebook.com/Transfermarkt.global" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
# <img class="header__icon header__icon--facebook" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
# <img class="header__icon header__icon--twitter" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
# <img class="header__icon header__icon--instagram" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
# <img class="header__icon header__icon--rss" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
# </a>
# </div>
# <div class="tm-header__input-wrapper" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
# </form>
# <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
# </a>
# </div>
# </header>
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><!-- /58778164/Desktop-Skyscraper-1 -->
# <div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });
#                           </script>
# </div></div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><!-- /58778164/Desktop-Skyscraper-2 -->
# <div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });
#                           </script>
# </div></div> </div>
# <div class="row hide-on-print navihalter">
# <div class="page_wrapper">
# <div class="large-12 columns megamenu_container megamenu_dark_bar megamenu_dark">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <ul class="megamenu" id="mainmenue" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <li id="mobile_hauptmenu_button">
# <ul id="hauptmenuepunkte">
# <li class="megamenu_drop_list" id="naviid_news">
# <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#                             News                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_transfers">
# <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#                             Transfers &amp; rumours                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="aktiv megamenu_drop_list" id="naviid_marktwerte">
# <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#                             Market values                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_wettbewerbe">
# <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#                             Competitions                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_foren">
# <a class="megamenu_drop tm-main-nav-el" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#                             Forums                        </a>
# </li>
# <li class="megamenu_drop_list" id="naviid_meintm">
# <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('MeinTM','click','menu');
# ">
#                             My TM                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="">
# <a class="live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy">
# <svg enable-background="new 0 0 100 100" height="100px" id="Layer_1" style="fill: white; width: 20px; height: 20px;" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M78.016,49.132L51.961,12.714c-0.471-0.66-1.233-1.049-2.043-1.051c-0.006,0-0.006,0-0.006,0
#                                 c-0.815,0.002-1.575,0.396-2.048,1.059L21.977,49.14c-0.546,0.767-0.616,1.776-0.183,2.612c0.426,0.835,1.292,1.361,2.236,1.361
#                                 h12.183l-0.001,32.709c0,1.39,1.125,2.515,2.516,2.515l22.541-0.001c1.389,0.001,2.515-1.124,2.516-2.517l0-32.705h12.187
#                                 c0.94,0,1.803-0.53,2.237-1.367C78.641,50.911,78.566,49.9,78.016,49.132z"></path>
# </g>
# </svg>
# </a>
# <div class="tm-login" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <svg class="tm-login__image" enable-background="new 0 0 100 100" fill="#FFF" height="100px" id="Layer_1" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M80.161,60.441l-15.66-7.47l-6.622-3.159c2.892-1.822,5.241-4.634,6.778-8.022c1.22-2.69,1.946-5.734,1.946-8.99
#                 c0-1.827-0.29-3.562-0.694-5.236C63.94,19.453,57.605,13.477,50,13.477c-7.461,0-13.701,5.763-15.792,13.645
#                 c-0.482,1.808-0.815,3.688-0.815,5.68c0,3.459,0.808,6.684,2.181,9.489c1.587,3.254,3.94,5.937,6.804,7.662l-6.342,2.953
#                 l-16.168,7.53c-1.404,0.658-2.327,2.242-2.327,4.011v15.062v2.703c0,2.381,1.659,4.312,3.708,4.312h57.505
#                 c2.048,0,3.708-1.93,3.708-4.312v-2.703V64.446C82.46,62.683,81.552,61.114,80.161,60.441z"></path>
# </g>
# </svg>
# <span class="tm-login__cta">
#         Log in    </span>
# </div>
# </div>
# </div>
# </div>
# <div class="row popuphalter">
# <div class="small-12" id="loginbox"></div>
# <div id="registerbox"></div>
# <div id="passwortVergessenBox"></div>
# </div>
# <div class="row">
# <div class="large-12 columns" id="breadcrumb">
# <div class="breadcrumb-box">
# <div class="breadcrumb">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# </div>
# </div>
# </div>
# <div class="werbung werbung-billboard"><!-- /58778164/Desktop-Billboard-1 -->
# <div id="div-gpt-ad-1621524903956-0" style="min-width: 728px; min-height: 90px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621524903956-0"); });
#                           </script>
# </div></div>
# <div id="modalHolder"></div>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <h2 class="content-box-headline">
#                 Most valuable players            </h2>
# <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# <option value="11">Left Winger</option>
# <option value="12">Right Winger</option>
# <option value="99">Winger</option>
# <option value="13">Second Striker</option>
# <option value="14">Centre-Forward</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Age group:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="altersklasse" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="u17">u17</option>
# <option value="u18">u18</option>
# <option value="u19">u19</option>
# <option value="u20">u20</option>
# <option value="u21">u21</option>
# <option value="u23">u23</option>
# <option value="23-30">23-30</option>
# <option value="o30">o30</option>
# <option value="o32">o32</option>
# <option value="o34">o34</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Year:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="jahrgang" tabindex="0">
# <option value="0">All</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1989">1989</option>
# <option value="1988">1988</option>
# <option value="1987">1987</option>
# <option value="1986">1986</option>
# <option value="1985">1985</option>
# <option value="1984">1984</option>
# <option value="1983">1983</option>
# <option value="1982">1982</option>
# <option value="1981">1981</option>
# <option value="1980">1980</option>
# <option value="1979">1979</option>
# <option value="1978">1978</option>
# <option value="1977">1977</option>
# <option value="1976">1976</option>
# <option value="1975">1975</option>
# <option value="1973">1973</option>
# <option value="1972">1972</option>
# <option value="1968">1968</option>
# <option value="1967">1967</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Nationality:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="land_id" tabindex="0">
# <option value="0">All</option>
# <option value="1">Afghanistan</option>
# <option value="3">Albania</option>
# <option value="4">Algeria</option>
# <option value="239">American Samoa</option>
# <option value="234">American Virgin Islands</option>
# <option value="5">Andorra</option>
# <option value="6">Angola</option>
# <option value="232">Anguilla</option>
# ...
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/ayron-del-valle/profil/spieler/74440" title="Ayron del Valle">Ayron del Valle</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Forward                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/venados-fc-yucatan/transfers/verein/18662" title="Venados FC Yucatán"><img alt="Venados FC Yucatán" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/18662.png?lm=1436681083" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ayron-del-valle/transfers/spieler/74440/transfer_id/3705294?from=neustetransfersbox" title="Ayron del Valle">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/once-caldas/transfers/verein/6984" title="Once Caldas"><img alt="Once Caldas" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/6984.png?lm=1419937895" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/ayron-del-valle/transfers/spieler/74440/transfer_id/3705294?from=neustetransfersbox" title="Ayron del Valle">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Hyoran" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/338861-1543844791.jpg?lm=1" title="Hyoran"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/hyoran/profil/spieler/338861" title="Hyoran">Hyoran</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/clube-atletico-mineiro/transfers/verein/330" title="Clube Atlético Mineiro"><img alt="Clube Atlético Mineiro" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/330.png?lm=1411033853" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/hyoran/transfers/spieler/338861/transfer_id/3705283?from=neustetransfersbox" title="Hyoran">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/red-bull-bragantino/transfers/verein/8793" title="Red Bull Bragantino"><img alt="Red Bull Bragantino" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/8793.png?lm=1577915313" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/hyoran/transfers/spieler/338861/transfer_id/3705283?from=neustetransfersbox" title="Hyoran">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Maxime Crépeau" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/189014-1618858472.jpg?lm=1" title="Maxime Crépeau"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/maxime-crepeau/profil/spieler/189014" title="Maxime Crépeau">Maxime Crépeau</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vancouver-whitecaps-fc/transfers/verein/6321" title="Vancouver Whitecaps FC"><img alt="Vancouver Whitecaps FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/6321.png?lm=1420976934" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/maxime-crepeau/transfers/spieler/189014/transfer_id/3705247?from=neustetransfersbox" title="Maxime Crépeau">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/los-angeles-fc/transfers/verein/51828" title="Los Angeles FC"><img alt="Los Angeles FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/51828.png?lm=1511112738" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/maxime-crepeau/transfers/spieler/189014/transfer_id/3705247?from=neustetransfersbox" title="Maxime Crépeau">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         €909Th.                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Dec 31, 2022                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Alassane Ndao" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/569777-1599487446.jpeg?lm=1" title="Alassane Ndao"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/alassane-ndao/profil/spieler/569777" title="Alassane Ndao">Alassane Ndao</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Right Winger                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/al-ahli-dschidda/transfers/verein/18487" title="Al-Ahli Jeddah"><img alt="Al-Ahli Jeddah" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/18487.png?lm=1407562631" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/alassane-ndao/transfers/spieler/569777/transfer_id/3705148?from=neustetransfersbox" title="Alassane Ndao">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/antalyaspor/transfers/verein/589" title="Antalyaspor"><img alt="Antalyaspor" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/589.png?lm=1473110173" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/alassane-ndao/transfers/spieler/569777/transfer_id/3705148?from=neustetransfersbox" title="Alassane Ndao">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Jón Dadi Bödvarsson" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/114090-1469005306.jpg?lm=1" title="Jón Dadi Bödvarsson"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/jon-dadi-bodvarsson/profil/spieler/114090" title="Jón Dadi Bödvarsson">J. Bödvarsson</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Forward                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/fc-millwall/transfers/verein/1028" title="Millwall FC"><img alt="Millwall FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1028.png?lm=1564722431" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/jon-dadi-bodvarsson/transfers/spieler/114090/transfer_id/3705119?from=neustetransfersbox" title="Jón Dadi Bödvarsson">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/bolton-wanderers/transfers/verein/355" title="Bolton Wanderers"><img alt="Bolton Wanderers" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/355.png?lm=1407653952" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/jon-dadi-bodvarsson/transfers/spieler/114090/transfer_id/3705119?from=neustetransfersbox" title="Jón Dadi Bödvarsson">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         ?                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2023                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><!-- /58778164/Desktop-MediumRectangle-2 -->
# <div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });
#                           </script>
# </div></div> </div>
# </div>
# <footer class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           general terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM Team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </footer>
# <div id="menue_overlay" style="display: none;"></div>
# </div>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
#     </script>
# <!--/SZM -->
# <script type="module">
#         var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};
#     </script>
# <script type="text/javascript">
#         if(typeof IOMm === 'function') {
#             IOMm('configure', { st: iam_data.st, dn: 'data-84a0f3455d.transfermarkt.com', mh:5 });
#             IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#         } else {
#             console.warn('IOMm is not defined');
#         }
#     </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script defer="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js"></script><script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1642680153" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/intersection-observer.min.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/lazyload.min.js?lm=1642680146" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1642680146" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                 const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                 const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var naviController = 'marktwertetop';
# 	var naviAction = 'wertvollstespieler';
# 	var naviPath = 'spieler-statistik/wertvollstespieler/marktwertetop';
# 	var naviId = '';
# 	var naviSaison = '';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page'});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 클래스 찾기
player_info = soup.find_all('tr', class_=['odd', 'even'])
player_info[0]
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Kylian Mbappé" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/342229-1632686046.jpg?lm=1" title="Kylian Mbappé"/></a></td><td class="hauptlink"><a href="/kylian-mbappe/profil/spieler/342229" title="Kylian Mbappé">Kylian Mbappé</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">23</td><td class="zentriert"><img alt="France" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/50.png?lm=1520611569" title="France"/></td><td class="zentriert"><a href="/fc-paris-saint-germain/startseite/verein/583" title="Paris Saint-Germain"><img alt="Paris Saint-Germain" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/583.png?lm=1522312728" title=" "/></a></td><td class="rechts hauptlink"><b>€160.00m</b><span class="icons_sprite grey-block-ten" title="€160.00m"> </span></td></tr>

# %%
print(len(player_info))
# Out:
# 25

# %%
number = []
name = []
position = []
age = []
nation = []
team = []
value = []

# %%
for info in player_info:
    player = info.find_all('td')
    # print(player)
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())
print(value)
# Out:
# ['€160.00m', '€150.00m', '€100.00m', '€100.00m', '€100.00m', '€100.00m', '€90.00m', '€90.00m', '€90.00m', '€85.00m', '€85.00m', '€85.00m', '€85.00m', '€85.00m', '€80.00m', '€80.00m', '€80.00m', '€80.00m', '€80.00m', '€80.00m', '€75.00m', '€75.00m', '€75.00m', '€75.00m', '€75.00m']

# %%
df = pd.DataFrame(
    {
        "number" : number,
        "name" : name,
        "position" : position,
        "age" : age,
        "nation" : nation,
        "team" : team,
        "value" : value
    }

)

# %%
df
# Out:
#    number                    name            position age        nation  \
# 0       1           Kylian Mbappé      Centre-Forward  23        France
# 1       2          Erling Haaland      Centre-Forward  21        Norway
# 2       3         Vinicius Junior         Left Winger  21        Brazil
# 3       4           Mohamed Salah        Right Winger  29         Egypt
# 4       5              Harry Kane      Centre-Forward  28       England
# 5       6           Romelu Lukaku      Centre-Forward  28       Belgium
# 6       7         Bruno Fernandes  Attacking Midfield  27      Portugal
# 7       8         Kevin De Bruyne  Attacking Midfield  30       Belgium
# 8       9                  Neymar         Left Winger  29        Brazil
# 9      10              Phil Foden    Central Midfield  21       England
# 10     11            Jadon Sancho         Left Winger  21       England
# 11     12         Marcus Rashford         Left Winger  24       England
# 12     13          Joshua Kimmich  Defensive Midfield  26       Germany
# 13     14         Raheem Sterling         Left Winger  27       England
# 14     15                   Pedri    Central Midfield  19         Spain
# 15     16        Lautaro Martínez      Centre-Forward  24     Argentina
# 16     17  Trent Alexander-Arnold          Right-Back  23       England
# 17     18           Jack Grealish         Left Winger  26       England
# 18     19              Sadio Mané         Left Winger  29       Senegal
# 19     20           Heung-min Son         Left Winger  29  Korea, South
# 20     21         Jude Bellingham    Central Midfield  18       England
# 21     22             Declan Rice  Defensive Midfield  23       England
# 22     23             Mason Mount  Attacking Midfield  23       England
# 23     24              Rúben Dias         Centre-Back  24      Portugal
# 24     25          Bernardo Silva  Attacking Midfield  27      Portugal
#
#                    team     value
# 0   Paris Saint-Germain  €160.00m
# 1     Borussia Dortmund  €150.00m
# 2           Real Madrid  €100.00m
# 3          Liverpool FC  €100.00m
# 4     Tottenham Hotspur  €100.00m
# 5            Chelsea FC  €100.00m
# 6     Manchester United   €90.00m
# 7       Manchester City   €90.00m
# 8   Paris Saint-Germain   €90.00m
# 9       Manchester City   €85.00m
# 10    Manchester United   €85.00m
# 11    Manchester United   €85.00m
# 12        Bayern Munich   €85.00m
# 13      Manchester City   €85.00m
# 14         FC Barcelona   €80.00m
# 15          Inter Milan   €80.00m
# 16         Liverpool FC   €80.00m
# 17      Manchester City   €80.00m
# 18         Liverpool FC   €80.00m
# 19    Tottenham Hotspur   €80.00m
# 20    Borussia Dortmund   €75.00m
# 21      West Ham United   €75.00m
# 22           Chelsea FC   €75.00m
# 23      Manchester City   €75.00m
# 24      Manchester City   €75.00m

# %%
df.to_csv("transfermarkt25.csv", index=False)
